# %% [markdown]
# <a href="https://colab.research.google.com/github/esuda/mineiracao_dados_complexos/blob/master/Big_Data_010_Trabalho_3_B3_Spark_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dados de Entrada
#
# *   [Pacote de dados](https://tinyurl.com/bd009-b3)
#   *   Selecione "Adicionar ao Drive"
# *   [Descrição dos dados](https://drive.google.com/file/d/1wu1yfR1A0A0Tl8Jl1ZNNuowr88YEFtXS/view?usp=sharing)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Instalação de pacotes

# %%
# !wget -q https://downloads.apache.org/spark/spark-3.2.0/spark-3.2.0-bin-hadoop3.2.tgz
# !tar xf spark-3.2.0-bin-hadoop3.2.tgz
# !pip install findspark pyspark
# Out:
# Requirement already satisfied: findspark in /usr/local/lib/python3.7/dist-packages (1.4.2)
# Requirement already satisfied: pyspark in /usr/local/lib/python3.7/dist-packages (3.2.0)
# Requirement already satisfied: py4j==0.10.9.2 in /usr/local/lib/python3.7/dist-packages (from pyspark) (0.10.9.2)

# %% [markdown]
# # Preparação do ambiente

# %%
# %env PYTHONHASHSEED=1234
# %env JAVA_HOME=/usr/lib/jvm/default-java
# %env SPARK_HOME=/content/spark-3.2.0-bin-hadoop3.2
# Out:
# env: PYTHONHASHSEED=1234
# env: JAVA_HOME=/usr/lib/jvm/default-java
# env: SPARK_HOME=/content/spark-3.2.0-bin-hadoop3.2

# %%
import findspark
findspark.init("/content/spark-3.2.0-bin-hadoop3.2")

# %%
from pyspark.sql import SparkSession
from pyspark.sql import Row
from pyspark.sql.types import *
from pyspark.sql.functions import *
from pyspark.sql import Window


from datetime import datetime

appName = 'Big Data'
master = 'local'

spark = SparkSession.builder     \
    .master(master) \
    .appName(appName) \
    .getOrCreate()

spark.sparkContext.setLogLevel("WARN")

# %% [markdown]
# # Leitura dos dados e criação de dataframes

# %%
def read_line(line) :
  tipo = line[0:2]
  if tipo == '01' :
    yield Row(tipreg=int(line[0:2]),
               data=datetime.strptime(line[2:10], '%Y%m%d'),
               codbdi=int(line[10:12]),
               codneg=line[12:24].strip(),
               tpmerc=int(line[24:27]),
               especi=line[39:49].replace('*', '').replace(' ',''),
               preult=float(line[108:121])/100)

# %%
# Modifique esta linha para incluir dados de outros anos na solução final

input_data = spark.sparkContext.textFile('/content/drive/My Drive/b3/COTAHIST*2012*')

cotacoes = input_data.flatMap(read_line).toDF()
cotacoes.printSchema()
cotacoes.show()
# Out:
# root
#  |-- tipreg: long (nullable = true)
#  |-- data: timestamp (nullable = true)
#  |-- codbdi: long (nullable = true)
#  |-- codneg: string (nullable = true)
#  |-- tpmerc: long (nullable = true)
#  |-- especi: string (nullable = true)
#  |-- preult: double (nullable = true)
#
# +------+-------------------+------+-------+------+------+------+
# |tipreg|               data|codbdi| codneg|tpmerc|especi|preult|
# +------+-------------------+------+-------+------+------+------+
# |     1|2012-01-02 00:00:00|     2|  ABCB4|    10|PNEJN2| 11.85|
# |     1|2012-01-02 00:00:00|    96| ABCB4F|    20|PNEJN2| 11.61|
# |     1|2012-01-02 00:00:00|    12| ABCP11|    10|  CIER|   8.0|
# |     1|2012-01-02 00:00:00|     2| ABRE11|    10| UNTN2| 20.85|
# |     1|2012-01-02 00:00:00|    96|ABRE11F|    20| UNTN2| 20.55|
# |     1|2012-01-02 00:00:00|     2|  AEDU3|    10|  ONNM| 20.46|
# |     1|2012-01-02 00:00:00|    96| AEDU3F|    20|  ONNM|  20.3|
# |     1|2012-01-02 00:00:00|    12| AEFI11|    10|  CIER| 100.8|
# |     1|2012-01-02 00:00:00|     2|  AELP3|    10|    ON|  45.5|
# |     1|2012-01-02 00:00:00|     2|  AFLT3|    10|    ON|   3.5|
# |     1|2012-01-02 00:00:00|    96| AFLT3F|    20|    ON|   3.5|
# |     1|2012-01-02 00:00:00|     2| AGEN11|    10|   DR3|  0.15|
# |     1|2012-01-02 00:00:00|     2|  AGRO3|    10|  ONNM|  9.74|
# |     1|2012-01-02 00:00:00|     2|  ALLL3|    10|  ONNM|  9.35|
# |     1|2012-01-02 00:00:00|    96| ALLL3F|    20|  ONNM|  9.43|
# |     1|2012-01-02 00:00:00|    62| ALLL3T|    30|  ONNM|  9.48|
# |     1|2012-01-02 00:00:00|     2|  ALPA4|    10|  PNN1| 12.02|
# |     1|2012-01-02 00:00:00|    96| ALPA4F|    20|  PNN1| 12.05|
# |     1|2012-01-02 00:00:00|     2|  ALSC3|    10|  ONNM| 14.15|
# |     1|2012-01-02 00:00:00|    96| ALSC3F|    20|  ONNM|  14.3|
# +------+-------------------+------+-------+------+------+------+
# only showing top 20 rows

# %% [markdown]
# # Implementação

# %% [markdown]
# ## Retirando os registros com NA

# %%
cotacoes = cotacoes.na.drop()

# %% [markdown]
# ## Primeiro Filtro
# * Tipo Registro = 1 (Cotacao Historica)
# * Codigo BDI = 02 (Lote Padrao)
# * Tipo de Mercado = 010 (Mercado a Vista)

# %%
cotacoes.printSchema()
# Out:
# root
#  |-- tipreg: long (nullable = true)
#  |-- data: timestamp (nullable = true)
#  |-- codbdi: long (nullable = true)
#  |-- codneg: string (nullable = true)
#  |-- tpmerc: long (nullable = true)
#  |-- especi: string (nullable = true)
#  |-- preult: double (nullable = true)

# %%
cotacoes_aux_01 = cotacoes.filter(cotacoes.tipreg == 1)\
                          .filter(cotacoes.codbdi == 2)\
                          .filter(cotacoes.tpmerc == 10)

# %%
cotacoes_aux_01.show()
# Out:
# +------+-------------------+------+------+------+------+------+
# |tipreg|               data|codbdi|codneg|tpmerc|especi|preult|
# +------+-------------------+------+------+------+------+------+
# |     1|2012-01-02 00:00:00|     2| ABCB4|    10|PNEJN2| 11.85|
# |     1|2012-01-02 00:00:00|     2|ABRE11|    10| UNTN2| 20.85|
# |     1|2012-01-02 00:00:00|     2| AEDU3|    10|  ONNM| 20.46|
# |     1|2012-01-02 00:00:00|     2| AELP3|    10|    ON|  45.5|
# |     1|2012-01-02 00:00:00|     2| AFLT3|    10|    ON|   3.5|
# |     1|2012-01-02 00:00:00|     2|AGEN11|    10|   DR3|  0.15|
# |     1|2012-01-02 00:00:00|     2| AGRO3|    10|  ONNM|  9.74|
# |     1|2012-01-02 00:00:00|     2| ALLL3|    10|  ONNM|  9.35|
# |     1|2012-01-02 00:00:00|     2| ALPA4|    10|  PNN1| 12.02|
# |     1|2012-01-02 00:00:00|     2| ALSC3|    10|  ONNM| 14.15|
# |     1|2012-01-02 00:00:00|     2| AMAR3|    10|  ONNM| 17.69|
# |     1|2012-01-02 00:00:00|     2| AMBV3|    10|    ON|  54.4|
# |     1|2012-01-02 00:00:00|     2| AMBV4|    10|    PN|  67.6|
# |     1|2012-01-02 00:00:00|     2| AMIL3|    10|  ONNM| 16.92|
# |     1|2012-01-02 00:00:00|     2| ARZZ3|    10|ONEJNM|  23.7|
# |     1|2012-01-02 00:00:00|     2| AUTM3|    10|ONEJNM| 14.37|
# |     1|2012-01-02 00:00:00|     2| BAUH4|    10|    PN|   3.1|
# |     1|2012-01-02 00:00:00|     2| BAZA3|    10|    ON|  0.39|
# |     1|2012-01-02 00:00:00|     2| BBAS3|    10|ONEJNM| 24.29|
# |     1|2012-01-02 00:00:00|     2| BBDC3|    10|  ONN1| 25.31|
# +------+-------------------+------+------+------+------+------+
# only showing top 20 rows

# %% [markdown]
# ## Segundo Filtro
# * Apenas acoes ordinarias normativas ou ordinarias normativas novo mercado (retirar acoes que tenham especificacoes mistas);
# * Desconsiderar acoes com especificacao igual " " ou "*"

# %%
cotacoes_nao_on = cotacoes_aux_01.filter((col("especi") != "ON") & (col("especi") != "ONNM"))\
                          .select(col("codneg").alias("codneg_nao_on"),
                                  expr("1").alias("flag_nao_on"))\
                          .distinct()

# %%
cotacoes_nao_on.show()
# Out:
# +-------------+-----------+
# |codneg_nao_on|flag_nao_on|
# +-------------+-----------+
# |      SLBG11B|          1|
# |        ITEC3|          1|
# |        FRAS3|          1|
# |        EUCA3|          1|
# |        SHOW3|          1|
# |        BRSR5|          1|
# |        CTAX4|          1|
# |        TNLP4|          1|
# |      MRCK11B|          1|
# |        BRML3|          1|
# |        HOOT4|          1|
# |        ENGI4|          1|
# |        NETC3|          1|
# |        DUQE4|          1|
# |        TCSA3|          1|
# |        ITSA4|          1|
# |        ODPV3|          1|
# |      AMZO11B|          1|
# |        MWET4|          1|
# |        CTNM4|          1|
# +-------------+-----------+
# only showing top 20 rows

# %%
cotacoes_aux_02 = cotacoes_aux_01.join(cotacoes_nao_on, 
                                       on=[cotacoes_aux_01.codneg == cotacoes_nao_on.codneg_nao_on], 
                                       how="left")

# %%
cotacoes_aux_02.filter("flag_nao_on = 1 and (especi = 'ON' or especi = 'ONNM')").select("codneg").distinct().show()
# Out:
# +------+
# |codneg|
# +------+
# | MILS3|
# | LIGT3|
# | HRTP3|
# | MYPK3|
# | ENBR3|
# | MAGG3|
# | RSID3|
# | RJCP3|
# | OHLB3|
# | LUPA3|
# | RDNI3|
# | TCNO3|
# | SBSP3|
# | ETER3|
# | BRGE3|
# | GRND3|
# | MRVE3|
# | GETI3|
# | ARZZ3|
# | LPSB3|
# +------+
# only showing top 20 rows

# %%
cotacoes_aux_02.filter("codneg = 'AFLT3'").select("especi").distinct().show()
# Out:
# +------+
# |especi|
# +------+
# |  ONED|
# |    ON|
# +------+

# %%
cotacoes_invalidas = cotacoes_aux_02.filter(col("especi").isin("", " ", "*"))\
                          .select(col("codneg").alias("codneg_invalido"),
                                  expr("1").alias("flag_invalido"))\
                          .distinct()

# %%
# Para 2012 nao ha acoes com especificacao igaul a " " ou "*"
# mas manteremos o cruzamento para os outros anos
cotacoes_invalidas.show()
# Out:
# +---------------+-------------+
# |codneg_invalido|flag_invalido|
# +---------------+-------------+
# +---------------+-------------+

# %%
cotacoes_aux_03 = cotacoes_aux_02.join(cotacoes_invalidas, 
                                       on=[cotacoes_aux_02.codneg == cotacoes_invalidas.codneg_invalido], 
                                       how="left")

# %%
cotacoes_aux_03.show()
# Out:
# +------+-------------------+------+------+------+------+------+-------------+-----------+---------------+-------------+
# |tipreg|               data|codbdi|codneg|tpmerc|especi|preult|codneg_nao_on|flag_nao_on|codneg_invalido|flag_invalido|
# +------+-------------------+------+------+------+------+------+-------------+-----------+---------------+-------------+
# |     1|2012-01-02 00:00:00|     2| AMBV4|    10|    PN|  67.6|        AMBV4|          1|           null|         null|
# |     1|2012-01-02 00:00:00|     2| ARZZ3|    10|ONEJNM|  23.7|        ARZZ3|          1|           null|         null|
# |     1|2012-01-02 00:00:00|     2| AGRO3|    10|  ONNM|  9.74|         null|       null|           null|         null|
# |     1|2012-01-02 00:00:00|     2| ALLL3|    10|  ONNM|  9.35|        ALLL3|          1|           null|         null|
# |     1|2012-01-02 00:00:00|     2| AFLT3|    10|    ON|   3.5|        AFLT3|          1|           null|         null|
# |     1|2012-01-02 00:00:00|     2| BBDC3|    10|  ONN1| 25.31|        BBDC3|          1|           null|         null|
# |     1|2012-01-02 00:00:00|     2| ALPA4|    10|  PNN1| 12.02|        ALPA4|          1|           null|         null|
# |     1|2012-01-02 00:00:00|     2| BAZA3|    10|    ON|  0.39|        BAZA3|          1|           null|         null|
# |     1|2012-01-02 00:00:00|     2| AMIL3|    10|  ONNM| 16.92|        AMIL3|          1|           null|         null|
# |     1|2012-01-02 00:00:00|     2| BAUH4|    10|    PN|   3.1|        BAUH4|          1|           null|         null|
# |     1|2012-01-02 00:00:00|     2| BBDC4|    10|  PNN1| 30.71|        BBDC4|          1|           null|         null|
# |     1|2012-01-02 00:00:00|     2| AMBV3|    10|    ON|  54.4|        AMBV3|          1|           null|         null|
# |     1|2012-01-02 00:00:00|     2| AUTM3|    10|ONEJNM| 14.37|        AUTM3|          1|           null|         null|
# |     1|2012-01-02 00:00:00|     2| AELP3|    10|    ON|  45.5|        AELP3|          1|           null|         null|
# |     1|2012-01-02 00:00:00|     2| AMAR3|    10|  ONNM| 17.69|        AMAR3|          1|           null|         null|
# |     1|2012-01-02 00:00:00|     2|AGEN11|    10|   DR3|  0.15|       AGEN11|          1|           null|         null|
# |     1|2012-01-02 00:00:00|     2| BBAS3|    10|ONEJNM| 24.29|        BBAS3|          1|           null|         null|
# |     1|2012-01-02 00:00:00|     2| AEDU3|    10|  ONNM| 20.46|        AEDU3|          1|           null|         null|
# |     1|2012-01-02 00:00:00|     2| ABCB4|    10|PNEJN2| 11.85|        ABCB4|          1|           null|         null|
# |     1|2012-01-02 00:00:00|     2|ABRE11|    10| UNTN2| 20.85|       ABRE11|          1|           null|         null|
# +------+-------------------+------+------+------+------+------+-------------+-----------+---------------+-------------+
# only showing top 20 rows

# %%
cotacoes_aux_04 = cotacoes_aux_03.filter("flag_nao_on is null and flag_invalido is null")\
                        .drop("codneg_nao_on", "flag_nao_on", "codneg_invalido", "flag_invalido")

# %%
cotacoes_aux_04.select("codneg").distinct().show()
# Out:
# +------+
# |codneg|
# +------+
# | IENG3|
# | POSI3|
# | CMGR3|
# | AORE3|
# | RNAR3|
# | BNBR3|
# | GSHP3|
# | VULC3|
# | SOND3|
# | PTNT3|
# | RHDS3|
# | DTCY3|
# | LUXM3|
# | MLFT3|
# | AGRO3|
# | VSPT3|
# | LFFE3|
# | GLOB3|
# | AMCE3|
# | SULT3|
# +------+
# only showing top 20 rows

# %% [markdown]
# ## Calculo da volatilidade dos papeis

# %%
janela_cotacao = Window.partitionBy('codneg').orderBy("data")

cotacoes_aux_04 = cotacoes_aux_04.withColumn("preult_ant", lag("preult", 1).over(janela_cotacao))\
                                  .withColumn("dif_rel", (col("preult")/col("preult_ant"))-1)\
                                  .filter("dif_rel is not null")

# %%
cotacoes_aux_04.show()
# Out:
# +------+-------------------+------+------+------+------+------+----------+--------------------+
# |tipreg|               data|codbdi|codneg|tpmerc|especi|preult|preult_ant|             dif_rel|
# +------+-------------------+------+------+------+------+------+----------+--------------------+
# |     1|2012-02-01 00:00:00|     2| AFLU3|    10|    ON|   5.0|      4.93|0.014198782961460488|
# |     1|2012-02-13 00:00:00|     2| AFLU3|    10|    ON|  5.27|       5.0|0.053999999999999826|
# |     1|2012-02-14 00:00:00|     2| AFLU3|    10|    ON|   5.0|      5.27|-0.05123339658444015|
# |     1|2012-02-17 00:00:00|     2| AFLU3|    10|    ON|   5.0|       5.0|                 0.0|
# |     1|2012-03-01 00:00:00|     2| AFLU3|    10|    ON|   5.0|       5.0|                 0.0|
# |     1|2012-03-13 00:00:00|     2| AFLU3|    10|    ON|   5.2|       5.0|0.040000000000000036|
# |     1|2012-03-14 00:00:00|     2| AFLU3|    10|    ON|   5.2|       5.2|                 0.0|
# |     1|2012-05-09 00:00:00|     2| AFLU3|    10|    ON|  4.83|       5.2|-0.07115384615384612|
# |     1|2012-06-11 00:00:00|     2| AFLU3|    10|    ON|  4.61|      4.83|-0.04554865424430632|
# |     1|2012-06-29 00:00:00|     2| AFLU3|    10|    ON|   6.1|      4.61| 0.32321041214750523|
# |     1|2012-08-06 00:00:00|     2| AFLU3|    10|    ON|  6.15|       6.1| 0.00819672131147553|
# |     1|2012-08-16 00:00:00|     2| AFLU3|    10|    ON|  6.15|      6.15|                 0.0|
# |     1|2012-08-27 00:00:00|     2| AFLU3|    10|    ON|  6.35|      6.15| 0.03252032520325199|
# |     1|2012-09-20 00:00:00|     2| AFLU3|    10|    ON|   6.1|      6.35|-0.03937007874015752|
# |     1|2012-10-01 00:00:00|     2| AFLU3|    10|    ON|   6.1|       6.1|                 0.0|
# |     1|2012-11-12 00:00:00|     2| AFLU3|    10|    ON|  5.41|       6.1|-0.11311475409836058|
# |     1|2012-11-30 00:00:00|     2| AFLU3|    10|    ON|  5.41|      5.41|                 0.0|
# |     1|2012-12-13 00:00:00|     2| AFLU3|    10|    ON|   5.8|      5.41| 0.07208872458410354|
# |     1|2012-12-18 00:00:00|     2| AFLU3|    10|    ON|   5.8|       5.8|                 0.0|
# |     1|2012-12-19 00:00:00|     2| AFLU3|    10|    ON|  5.79|       5.8|-0.00172413793103...|
# +------+-------------------+------+------+------+------+------+----------+--------------------+
# only showing top 20 rows

# %%
cotacoes.filter("codneg = 'AFLU3'").sort("data", "dif_rel").show()
# Out:
# +------+-------------------+------+------+------+------+------+
# |tipreg|               data|codbdi|codneg|tpmerc|especi|preult|
# +------+-------------------+------+------+------+------+------+
# |     1|2012-01-19 00:00:00|     2| AFLU3|    10|    ON|  4.93|
# |     1|2012-02-01 00:00:00|     2| AFLU3|    10|    ON|   5.0|
# |     1|2012-02-13 00:00:00|     2| AFLU3|    10|    ON|  5.27|
# |     1|2012-02-14 00:00:00|     2| AFLU3|    10|    ON|   5.0|
# |     1|2012-02-17 00:00:00|     2| AFLU3|    10|    ON|   5.0|
# |     1|2012-03-01 00:00:00|     2| AFLU3|    10|    ON|   5.0|
# |     1|2012-03-13 00:00:00|     2| AFLU3|    10|    ON|   5.2|
# |     1|2012-03-14 00:00:00|     2| AFLU3|    10|    ON|   5.2|
# |     1|2012-05-09 00:00:00|     2| AFLU3|    10|    ON|  4.83|
# |     1|2012-06-11 00:00:00|     2| AFLU3|    10|    ON|  4.61|
# |     1|2012-06-29 00:00:00|     2| AFLU3|    10|    ON|   6.1|
# |     1|2012-08-06 00:00:00|     2| AFLU3|    10|    ON|  6.15|
# |     1|2012-08-16 00:00:00|     2| AFLU3|    10|    ON|  6.15|
# |     1|2012-08-27 00:00:00|     2| AFLU3|    10|    ON|  6.35|
# |     1|2012-09-20 00:00:00|     2| AFLU3|    10|    ON|   6.1|
# |     1|2012-10-01 00:00:00|     2| AFLU3|    10|    ON|   6.1|
# |     1|2012-11-12 00:00:00|     2| AFLU3|    10|    ON|  5.41|
# |     1|2012-11-30 00:00:00|     2| AFLU3|    10|    ON|  5.41|
# |     1|2012-12-13 00:00:00|     2| AFLU3|    10|    ON|   5.8|
# |     1|2012-12-18 00:00:00|     2| AFLU3|    10|    ON|   5.8|
# +------+-------------------+------+------+------+------+------+
# only showing top 20 rows

# %%
cotacoes_var = cotacoes_aux_04.select("codneg", "dif_rel")\
                              .groupby("codneg")\
                              .agg(stddev("dif_rel"))

# %%
cotacoes_var.show(cotacoes.count())
# Out:
# +------+--------------------+
# |codneg|stddev_samp(dif_rel)|
# +------+--------------------+
# | AFLU3| 0.08087051237373724|
# | AGRO3| 0.02208735046287768|
# | AHEB3|                null|
# | AMCE3|   0.255495562335909|
# | AMPI3| 0.02800414677881901|
# | AORE3| 0.09888682662996408|
# | ARTR3|0.014347739490924773|
# | BHGR3| 0.01772160841885122|
# | BIOM3|  0.1617974325481534|
# | BNBR3| 0.05031393685985516|
# | BTOW3| 0.04113677097185169|
# | BTTL3| 0.05684431029345428|
# | CAFE3| 0.16476368593970986|
# | CASN3|  0.3559851823321133|
# | CBMA3| 0.08516947123388358|
# | CCIM3| 0.01953387259244671|
# | CCXC3|0.042165459296822375|
# | CEBR3| 0.09727952050060319|
# | CEGR3| 0.11031016645119282|
# | CEPE3|                null|
# | CIQU3|0.045051245625291336|
# | CMGR3| 0.07378962369446043|
# | CSAB3|0.002216187049174592|
# | CTKA3| 0.39964237257248564|
# | CTNM3| 0.05858669222045167|
# | CTPC3|                 0.0|
# | DOHL3|                null|
# | DTCY3|0.052163333954856735|
# | EBTP3| 0.03692121318602152|
# | ECPR3|  0.2572178996119165|
# | FHER3|0.021673725916768746|
# | FIBR3|0.024446369669929167|
# | FRIO3| 0.02419887287721681|
# | GFSA3| 0.04140750447939678|
# | GLOB3|  0.0514895494990533|
# | GPAR3|                null|
# | GPCP3|  0.0421853427447067|
# | GSHP3|  0.0238209261724168|
# | HAGA3| 0.04830260364967404|
# | HETA3| 0.21626075965974006|
# | HYPE3|0.024744812181633484|
# | IDNT3| 0.03122188474957479|
# | IENG3| 0.07315475123781875|
# | IGBR3| 0.04024677701268071|
# | IGUA3| 0.19057902900037607|
# | IMBI3| 0.05681118150484031|
# | INET3|  0.0630162708859797|
# | JBSS3|0.031059066826457354|
# | JOPA3|0.009931625152891546|
# | LIXC3| 0.13628967256464614|
# | LLXL3|  0.0354025212136549|
# | LOGN3|0.022050528181240356|
# | LUXM3| 0.15926607448650418|
# | MAPT3|  0.1662013814895107|
# | MERC3|                 0.0|
# | MLFT3|  0.1350447214016177|
# | MRFG3| 0.03154048474699424|
# | MSPA3| 0.14691465925769095|
# | MWET3|                null|
# | NORD3|  0.3726224753836937|
# | PEAB3|0.013507226335979703|
# | POSI3| 0.02600076437920939|
# | PRTX3| 0.04971672775192129|
# | PTNT3|  0.0781183674870575|
# | QUAL3|0.020063157682844824|
# | REDE3|  0.1149083499701185|
# | RHDS3| 0.06524702486271396|
# | RNAR3| 0.04151865957990124|
# | ROMI3| 0.02947992579748839|
# | RPMG3| 0.02582628343269751|
# | SOND3| 0.11437736013770286|
# | SULT3| 0.08754020169780088|
# | TMAR3|0.023234065658365576|
# | TNLP3| 0.01886123260924439|
# | TOYB3|  0.2128723089612475|
# | TRIS3| 0.02708531595136196|
# | VIGR3| 0.03431164907356078|
# | VINE3| 0.04377959433237534|
# | VSPT3| 0.03325523528383264|
# | VULC3| 0.05032958065193485|
# | VVAR3| 0.02745200947859141|
# | WISA3| 0.11648632554578305|
# +------+--------------------+

# %%
cotacoes_aux_04.filter("codneg in ('MERC3', 'MWET3', 'CEPE3', 'DOHL3')").sort("codneg", "data").show()
# Out:
# +------+-------------------+------+------+------+------+------+----------+--------------------+
# |tipreg|               data|codbdi|codneg|tpmerc|especi|preult|preult_ant|             dif_rel|
# +------+-------------------+------+------+------+------+------+----------+--------------------+
# |     1|2012-09-21 00:00:00|     2| CEPE3|    10|    ON| 24.53|      20.0| 0.22650000000000015|
# |     1|2012-06-12 00:00:00|     2| DOHL3|    10|    ON|   3.0|      2.01|  0.4925373134328359|
# |     1|2012-06-21 00:00:00|     2| MERC3|    10|    ON|   6.5|       6.5|                 0.0|
# |     1|2012-08-06 00:00:00|     2| MERC3|    10|    ON|   6.5|       6.5|                 0.0|
# |     1|2012-04-16 00:00:00|     2| MWET3|    10|    ON|   4.0|      3.99|0.002506265664160...|
# +------+-------------------+------+------+------+------+------+----------+--------------------+

# %% [markdown]
# ## --------- Ate Aqui Feito -----------

# %%
cotacoes_on = cotacoes.filter("especi == 'ON' or especi == 'ONNM'")
candidate_names = cotacoes_on.select("codneg").distinct().rdd.flatMap(lambda x: x).collect()

# %%
cotacoes.filter(cotacoes.codneg.isin(candidate_names)).show(20)
# Out:
# +-------------------+------+------+------+-------+------+
# |               data|codbdi|codneg|tpmerc| especi|preult|
# +-------------------+------+------+------+-------+------+
# |2020-01-02 00:00:00|     2| AALR3|    10|   ONNM|  19.0|
# |2020-01-02 00:00:00|     2| ABEV3|    10|   ONEJ|  19.2|
# |2020-01-02 00:00:00|     2| ADHM3|    10|     ON|  2.48|
# |2020-01-02 00:00:00|     2| AFLT3|    10|     ON| 11.23|
# |2020-01-02 00:00:00|     2| AGRO3|    10|   ONNM| 19.25|
# |2020-01-02 00:00:00|     2| ALSO3|    10|   ONNM| 50.01|
# |2020-01-02 00:00:00|     2| AMAR3|    10|   ONNM| 13.46|
# |2020-01-02 00:00:00|     2| ANIM3|    10|   ONNM|  29.6|
# |2020-01-02 00:00:00|     2| APER3|    10|   ONNM|  30.7|
# |2020-01-02 00:00:00|     2| ARZZ3|    10|   ONNM| 63.91|
# |2020-01-02 00:00:00|     2| ATOM3|    10|     ON|  1.72|
# |2020-01-02 00:00:00|     2| B3SA3|    10|ONEDJNM| 45.11|
# |2020-01-02 00:00:00|     2| BAZA3|    10|     ON|  39.0|
# |2020-01-02 00:00:00|     2| BBAS3|    10|   ONNM|  53.8|
# |2020-01-02 00:00:00|     2| BBRK3|    10|   ONNM|  6.02|
# |2020-01-02 00:00:00|     2| BBSE3|    10|   ONNM|  38.1|
# |2020-01-02 00:00:00|     2| BEEF3|    10|   ONNM| 12.57|
# |2020-01-02 00:00:00|     2| BEES3|    10|   ONEJ|  6.53|
# |2020-01-02 00:00:00|     2| BKBR3|    10|   ONNM| 17.35|
# |2020-01-02 00:00:00|     2| BMEB3|    10|     ON| 13.25|
# +-------------------+------+------+------+-------+------+
# only showing top 20 rows

# %%
print(*sorted(candidate_names))
# Out:
# AALR3 AALR3F AALR3T ABEV3 ABEV3F ABEV3T ABEVA100 ABEVA105 ABEVA105E ABEVA110 ABEVA110E ABEVA115 ABEVA120 ABEVA120E ABEVA125 ABEVA130 ABEVA132 ABEVA135 ABEVA135E ABEVA140 ABEVA142 ABEVA142E ABEVA145 ABEVA147 ABEVA147E ABEVA150 ABEVA152 ABEVA152E ABEVA155 ABEVA157 ABEVA157E ABEVA15E ABEVA160 ABEVA162 ABEVA162E ABEVA165 ABEVA167 ABEVA167E ABEVA17 ABEVA170 ABEVA172 ABEVA172E ABEVA175 ABEVA17E ABEVA18 ABEVA180 ABEVA182 ABEVA182E ABEVA185 ABEVA187 ABEVA187E ABEVA18E ABEVA19 ABEVA190 ABEVA192 ABEVA192E ABEVA195 ABEVA197 ABEVA19E ABEVA200 ABEVA202 ABEVA205 ABEVA210 ABEVA220 ABEVA23 ABEVA47 ABEVA47E ABEVA48 ABEVA48E ABEVA51 ABEVA52 ABEVA53 ABEVA980 ABEVA980E ABEVB125 ABEVB132 ABEVB135 ABEVB140 ABEVB145 ABEVB147 ABEVB150 ABEVB155 ABEVB160 ABEVB165 ABEVB17 ABEVB170 ABEVB175 ABEVB17E ABEVB18 ABEVB180 ABEVB185 ABEVB19 ABEVB190 ABEVB195 ABEVB198 ABEVB20 ABEVB21 ABEVB212 ABEVB22 ABEVB23 ABEVB46 ABEVB46E ABEVB47 ABEVB50 ABEVB51 ABEVB53 ABEVB86 ABEVB86E ABEVB87 ABEVB92 ABEVC127 ABEVC13 ABEVC137 ABEVC14 ABEVC145 ABEVC145E ABEVC15 ABEVC155 ABEVC158 ABEVC15E ABEVC16 ABEVC160 ABEVC161 ABEVC162 ABEVC165 ABEVC166 ABEVC17 ABEVC175 ABEVC176 ABEVC180 ABEVC181 ABEVC185 ABEVC190 ABEVC191 ABEVC195 ABEVC197 ABEVC198 ABEVC20 ABEVC200 ABEVC205 ABEVC207 ABEVC21 ABEVC215 ABEVC217 ABEVC22 ABEVC225 ABEVC235 ABEVC42 ABEVD10 ABEVD10E ABEVD110 ABEVD110E ABEVD12 ABEVD13 ABEVD135 ABEVD14 ABEVD15 ABEVD150 ABEVD153 ABEVD158 ABEVD160 ABEVD165 ABEVD168 ABEVD17 ABEVD170 ABEVD180 ABEVD182 ABEVD185 ABEVD187 ABEVD19 ABEVD190 ABEVD192 ABEVD20 ABEVD202 ABEVD203 ABEVD210 ABEVD212 ABEVD40 ABEVD40E ABEVD41 ABEVD42 ABEVD44 ABEVD45 ABEVD84 ABEVD84E ABEVD91 ABEVD94 ABEVD94E ABEVE11 ABEVE113 ABEVE113E ABEVE118 ABEVE118E ABEVE11E ABEVE12 ABEVE121 ABEVE123 ABEVE128 ABEVE12E ABEVE13 ABEVE133 ABEVE14 ABEVE15 ABEVE157 ABEVE16 ABEVE160 ABEVE162 ABEVE165 ABEVE167 ABEVE17 ABEVE170 ABEVE172 ABEVE176 ABEVE177 ABEVE18 ABEVE180 ABEVE188 ABEVE190 ABEVE202 ABEVE205 ABEVE207 ABEVE212 ABEVE230 ABEVE40 ABEVE40E ABEVE41 ABEVE41E ABEVE42 ABEVE43 ABEVE44 ABEVE53 ABEVF11 ABEVF113 ABEVF113E ABEVF118 ABEVF118E ABEVF11E ABEVF12 ABEVF123 ABEVF123E ABEVF128 ABEVF128E ABEVF12E ABEVF13 ABEVF133 ABEVF138 ABEVF13E ABEVF14 ABEVF143 ABEVF15 ABEVF160 ABEVF165 ABEVF167 ABEVF17 ABEVF177 ABEVF18 ABEVF180 ABEVF187 ABEVF19 ABEVF192 ABEVF202 ABEVF205 ABEVF210 ABEVF212 ABEVF215 ABEVF22 ABEVF310 ABEVF41 ABEVF41E ABEVF42 ABEVF42E ABEVF43 ABEVF44 ABEVF46 ABEVF49 ABEVG11 ABEVG11E ABEVG120 ABEVG120E ABEVG127 ABEVG130 ABEVG130E ABEVG135 ABEVG14 ABEVG140 ABEVG14E ABEVG150 ABEVG155 ABEVG158 ABEVG16 ABEVG160 ABEVG17 ABEVG180 ABEVG182 ABEVG185 ABEVG192 ABEVG20 ABEVG205 ABEVG207 ABEVG212 ABEVG220 ABEVG230 ABEVG240 ABEVG245 ABEVG41 ABEVG41E ABEVG42 ABEVG42E ABEVG43 ABEVG43E ABEVG44 ABEVG49 ABEVH11 ABEVH11E ABEVH12 ABEVH12E ABEVH13 ABEVH13E ABEVH14 ABEVH15 ABEVH153 ABEVH158 ABEVH16 ABEVH160 ABEVH178 ABEVH183 ABEVH185 ABEVH187 ABEVH193 ABEVH205 ABEVH212 ABEVH222 ABEVH232 ABEVH30 ABEVH41 ABEVH41E ABEVH42 ABEVH42E ABEVH43 ABEVH44 ABEVH45 ABEVH46 ABEVI100 ABEVI100E ABEVI105 ABEVI105E ABEVI110 ABEVI110E ABEVI115 ABEVI115E ABEVI120 ABEVI120E ABEVI125 ABEVI125E ABEVI130 ABEVI135 ABEVI140 ABEVI145 ABEVI150 ABEVI155 ABEVI160 ABEVI165 ABEVI167 ABEVI168 ABEVI170 ABEVI175 ABEVI185 ABEVI187 ABEVI203 ABEVI212 ABEVI215 ABEVI963 ABEVI963E ABEVI973 ABEVI973E ABEVJ100 ABEVJ100E ABEVJ105 ABEVJ110 ABEVJ110E ABEVJ115 ABEVJ115E ABEVJ120 ABEVJ120E ABEVJ125 ABEVJ125E ABEVJ130 ABEVJ130E ABEVJ135 ABEVJ138 ABEVJ140 ABEVJ145 ABEVJ150 ABEVJ155 ABEVJ160 ABEVJ168 ABEVJ17 ABEVJ170 ABEVJ173 ABEVJ175 ABEVJ188 ABEVJ190 ABEVJ195 ABEVJ198 ABEVJ200 ABEVJ203 ABEVJ212 ABEVJ213 ABEVJ215 ABEVJ218 ABEVJ958 ABEVJ958E ABEVK100 ABEVK100E ABEVK110 ABEVK110E ABEVK115 ABEVK115E ABEVK120 ABEVK120E ABEVK125 ABEVK125E ABEVK130 ABEVK130E ABEVK135 ABEVK135E ABEVK140 ABEVK140E ABEVK145 ABEVK145E ABEVK148 ABEVK148E ABEVK150 ABEVK150E ABEVK155 ABEVK160 ABEVK168 ABEVK17 ABEVK170 ABEVK175 ABEVK188 ABEVK190 ABEVK215 ABEVK216 ABEVK217 ABEVK218 ABEVK220 ABEVL105 ABEVL105E ABEVL110 ABEVL110E ABEVL ...

# %%
candidate_types = cotacoes.select("especi").distinct()
# Out:
# ---------------------------------------------------------------------------
# Py4JError                                 Traceback (most recent call last)
# <ipython-input-116-311a6a2b1079> in <module>()
# ----> 1 candidate_types = cotacoes.select("especi").distinct()
#
# /content/spark-3.2.0-bin-hadoop3.2/python/pyspark/sql/dataframe.py in select(self, *cols)
#    1683         [Row(name='Alice', age=12), Row(name='Bob', age=15)]
#    1684         """
# -> 1685         jdf = self._jdf.select(self._jcols(*cols))
#    1686         return DataFrame(jdf, self.sql_ctx)
#    1687
#
# /content/spark-3.2.0-bin-hadoop3.2/python/pyspark/sql/dataframe.py in _jcols(self, *cols)
#    1439         if len(cols) == 1 and isinstance(cols[0], list):
#    1440             cols = cols[0]
# -> 1441         return self._jseq(cols, _to_java_column)
#    1442
#    1443     def _sort_cols(self, cols, kwargs):
#
# /content/spark-3.2.0-bin-hadoop3.2/python/pyspark/sql/dataframe.py in _jseq(self, cols, converter)
#    1426     def _jseq(self, cols, converter=None):
#    1427         """Return a JVM Seq of Columns from a list of Column or names"""
# -> 1428         return _to_seq(self.sql_ctx._sc, cols, converter)
#    1429
#    1430     def _jmap(self, jm):
#
# /content/spark-3.2.0-bin-hadoop3.2/python/pyspark/sql/column.py in _to_seq(sc, cols, converter)
#      59     """
#      60     if converter:
# ---> 61         cols = [converter(c) for c in cols]
#      62     return sc._jvm.PythonUtils.toSeq(cols)
#      63
#
# /content/spark-3.2.0-bin-hadoop3.2/python/pyspark/sql/column.py in <listcomp>(.0)
#      59     """
#      60     if converter:
# ---> 61         cols = [converter(c) for c in cols]
#      62     return sc._jvm.PythonUtils.toSeq(cols)
#      63
#
# /content/spark-3.2.0-bin-hadoop3.2/python/pyspark/sql/column.py in _to_java_column(col)
#      41         jcol = col._jc
#      42     elif isinstance(col, str):
# ---> 43         jcol = _create_column_from_name(col)
#      44     else:
#      45         raise TypeError(
#
# /content/spark-3.2.0-bin-hadoop3.2/python/pyspark/sql/column.py in _create_column_from_name(name)
#      34 def _create_column_from_name(name):
#      35     sc = SparkContext._active_spark_context
# ---> 36     return sc._jvm.functions.col(name)
#      37
#      38
#
# /content/spark-3.2.0-bin-hadoop3.2/python/lib/py4j-0.10.9.2-src.zip/py4j/java_gateway.py in __getattr__(self, name)
#    1708             message = compute_exception_message(
#    1709                 "{0} does not exist in the JVM".format(name), error_message)
# -> 1710             raise Py4JError(message)
#    1711
#    1712
#
# Py4JError: functions does not exist in the JVM
